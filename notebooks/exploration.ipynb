# %% [markdown]
# # Exploration notebook
# Use this notebook for ad-hoc EDA. The canonical, reproducible profiling report is `python -m src.data_loader`, and the full training pipeline is `python -m src.train`.

# %%
import sys
sys.path.insert(0, '..')
from src.data_loader import load_raw_data, profile_dataset

df = load_raw_data()
profile_dataset(df)
